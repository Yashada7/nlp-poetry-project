# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

model_name = "distilgpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = model.config.eos_token_id

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

prompts = [
    "Beyond the last horizon,",
    "Under electric skies,",
    "When the forest breathes,",
    "At the edge of starlight,",
    "Where laughter lingers,",
    "Inside the quiet storm,",
    "Beneath the neon glow,",
    "As the shadows bloom,",
    "Among the drifting worlds,",
    "In the cradle of silence,",
    "Before the dream unravels,",
    "Where the past hums,",
    "Under the watchful moon,",
    "When the colors melt,",
    "At the doorway of becoming,"
]

prompts = [f"Write a poem starting with: {p}" for p in prompts]

for i, prompt in enumerate(prompts, start=1):
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = (inputs != tokenizer.pad_token_id).long()

    outputs = model.generate(
        inputs,
        attention_mask=attention_mask,
        max_length=100,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.9,
        no_repeat_ngram_size=3
    )

    generated_poem = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"\nPoem {i} (Prompt: {prompt})\n{generated_poem}\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 1 (Prompt: Write a poem starting with: Beyond the last horizon,)
# Write a poem starting with: Beyond the last horizon, of the earth
#
#
# We know,
# But I do not know
# My life,
# All my life
# I die and die
# My death
# My ashes
# And my dreams
# And I am like the stars of the universe
# To be at peace
# To have the words to say:
# In the end, I am the first one
# That is all I can do
# I'm born here, I'm the first to
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 2 (Prompt: Write a poem starting with: Under electric skies,)
# Write a poem starting with: Under electric skies, the night sky is dim and the stars and rays are shining on a huge screen, the sky is dull and the sun is not in harmony. This is the sound that we hear from the sky, and there are many different sounds and sounds, and many different songs.
# If the time passes, that will be the sound of a night sky that is dark and bright like the moon, and is dark like the sun and light like the sky.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 3 (Prompt: Write a poem starting with: When the forest breathes,)
# Write a poem starting with: When the forest breathes, the forest has a great sense of smell, and you can see this smell coming from the tree. The trees are not that bad either, but the leaves are one of the most important. The leaves are a good deal longer than the roots. As an example, the leaves show a very light pattern that makes the leaves look a bit green when you look at it, which can be extremely nice when the trees are growing.
# The most
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 4 (Prompt: Write a poem starting with: At the edge of starlight,)
# Write a poem starting with: At the edge of starlight, the whole moon is the Sun. When the moon's sun is dark enough to cover its entirety, the sun must be darkened. By the end of the poem, the starlight will be dimmed. For instance, a human is using an instrument called a telescopic mirror to see through a starlight. By this, a woman can see through the mirror of a man in full view of her.
#
#
# See also [
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 5 (Prompt: Write a poem starting with: Where laughter lingers,)
# Write a poem starting with: Where laughter lingers, and why you think you're in trouble (it could be the most famous example you've ever heard of).
#
#
# Now that you know about a poem, please take a look at how it comes to writing it.
# You can find the full text by clicking on any section of the page.
# As with most words in English, this is not a problem. There are a lot of other examples from some authors who are not familiar
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 6 (Prompt: Write a poem starting with: Inside the quiet storm,)
# Write a poem starting with: Inside the quiet storm, a beautiful storm. From the wind to the darkness, the storm will burst into the world without a doubt.
# The word 'wain'.
# "Wain".
# This is the word for a poem, a poem which has a strong connection with the human race. The word 'Wain'. This is the term used to describe a poem in a short poem about the "wain". The poem's name is the form of a
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 7 (Prompt: Write a poem starting with: Beneath the neon glow,)
# Write a poem starting with: Beneath the neon glow, he starts with: I go back, I go home, I come home. I tell my mother, I tell the father, I send me out, I don't have time to tell the wife, I never talk to him, I do not want to listen to her. I don, not know what he said to me. I go to my bed, I stay in bed, my legs are not functioning and I tell him I
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 8 (Prompt: Write a poem starting with: As the shadows bloom,)
# Write a poem starting with: As the shadows bloom, the flowers glow, the stars are gone. The leaves are gone, but the plants are gone: And the flowers are gone—nothing else is going to happen. The flowers are still gone. And the trees are gone! We have been told that this is not the end of the universe, but an end of our existence! But the world has gone. We're living on its own terms! There's nothing we can do but get up
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 9 (Prompt: Write a poem starting with: Among the drifting worlds,)
# Write a poem starting with: Among the drifting worlds, each of the waves must come together and separate, and each of them must unite together in a single place: The sky must be seen through the sky as it lies on the ocean's edge. The moon must be visible through the ocean and the sky must show itself, so that the sky's rays can be seen in the darkness of the earth. The stars must be blue, as they are, and their lights will shine. The light of
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 10 (Prompt: Write a poem starting with: In the cradle of silence,)
# Write a poem starting with: In the cradle of silence, love is a blessing:
#
#
# But you‡d hold it.
# Your love, Your love,
# And your love, For the Lord, is your gift:
# But the Lord‡s love
# That is your true love:
# And you stand in the path to the eternal truth.
# That was your true, Your joy is your joy:
# Your joy is the love of love:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 11 (Prompt: Write a poem starting with: Before the dream unravels,)
# Write a poem starting with: Before the dream unravels, try to imagine what is happening and to understand what's going to happen if it has no consequences; for the most part, what can you do to be successful; for those of us who have not experienced the effect of a dream dream in previous times, they may have seen a similar effect. They may have found the dream in the first place, but, in another moment, they had come to realize that the dream might have been completely
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 12 (Prompt: Write a poem starting with: Where the past hums,)
# Write a poem starting with: Where the past hums, where the past is left, when the past can be the past .
# The poem ends with: What you will write .
# You will write for your friends in your country or on a country or even a country .
# This is all written by you .
# All the time you have written in one word or another .
# But there is one thing we will never forget .
# There is one problem .
# We will never get past
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 13 (Prompt: Write a poem starting with: Under the watchful moon,)
# Write a poem starting with: Under the watchful moon, watchful sky, watchfully moon
#
#
# [A poem in the poem that is not written from an unknown source is considered to be the poem written from a foreign source.]
# [The poem written by a woman in the novel, "Fell" is the second-best poem to be written in Japan. The poem is known for its style and its manner and style. The female author is known as the "Sheep"
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Poem 14 (Prompt: Write a poem starting with: When the colors melt,)
# Write a poem starting with: When the colors melt, the color of the poem's color begins to melt. You don't need to know what color to use in your poem to write. You'll need to understand that your poem is about white, and the color that you're writing is about color.
# The color that's a color (red, green, yellow, and yellow) starts to melt with color, but then it starts to do so. The color that is in the poem begins
#
#
# Poem 15 (Prompt: Write a poem starting with: At the doorway of becoming,)
# Write a poem starting with: At the doorway of becoming, at the door of becoming
#
#
# A poem from a poem. A poem from the poem. An essay from a piece from an essay. An article from a essay. A piece from a letter from an article. An idea from a book. A concept from a story. An image from a novel. An album from a work. A list of books.
# A work.
# An image from an album. A collection of books
